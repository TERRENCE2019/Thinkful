# %% [markdown]
# <a href="https://colab.research.google.com/github/TERRENCE2019/Thinkful/blob/master/Python_and_Github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#This is called your data frame 
#This number sign is called a comment (its notes for coders or for yourself)
File=pd.read_csv("https://raw.githubusercontent.com/TERRENCE2019/Thinkful/master/nyc-jobs.csv")

# %%
File.head()
# Out:
#    Job ID  ...             Process Date
# 0   87990  ...  2019-07-30T00:00:00.000
# 1   97899  ...  2019-07-30T00:00:00.000
# 2  132292  ...  2019-07-30T00:00:00.000
# 3  132292  ...  2019-07-30T00:00:00.000
# 4  133921  ...  2019-07-30T00:00:00.000
#
# [5 rows x 28 columns]

# %%
File.fillna(0, inplace=True)

# %%
File
# Out:
#       Job ID  ...             Process Date
# 0      87990  ...  2019-07-30T00:00:00.000
# 1      97899  ...  2019-07-30T00:00:00.000
# 2     132292  ...  2019-07-30T00:00:00.000
# 3     132292  ...  2019-07-30T00:00:00.000
# 4     133921  ...  2019-07-30T00:00:00.000
# 5     133921  ...  2019-07-30T00:00:00.000
# 6     137433  ...  2019-07-30T00:00:00.000
# 7     138531  ...  2019-07-30T00:00:00.000
# 8     151131  ...  2019-07-30T00:00:00.000
# 9     151937  ...  2019-07-30T00:00:00.000
# 10    151937  ...  2019-07-30T00:00:00.000
# 11    152738  ...  2019-07-30T00:00:00.000
# 12    160910  ...  2019-07-30T00:00:00.000
# 13    167179  ...  2019-07-30T00:00:00.000
# 14    167179  ...  2019-07-30T00:00:00.000
# 15    170989  ...  2019-07-30T00:00:00.000
# 16    170989  ...  2019-07-30T00:00:00.000
# 17    171040  ...  2019-07-30T00:00:00.000
# 18    171944  ...  2019-07-30T00:00:00.000
# 19    172053  ...  2019-07-30T00:00:00.000
# 20    175362  ...  2019-07-30T00:00:00.000
# ...

# %%
File2 = File.replace(0,"")

# %%
File2.head()
# Out:
#    Job ID  ...             Process Date
# 0   87990  ...  2019-07-30T00:00:00.000
# 1   97899  ...  2019-07-30T00:00:00.000
# 2  132292  ...  2019-07-30T00:00:00.000
# 3  132292  ...  2019-07-30T00:00:00.000
# 4  133921  ...  2019-07-30T00:00:00.000
#
# [5 rows x 28 columns]

# %%
#https://stackoverflow.com/questions/13295735/how-can-i-replace-all-the-nan-values-with-zeros-in-a-column-of-a-pandas-datafra
